# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load dataset

# %%
df_customers = pd.read_csv('customers_raw.csv', header=0, index_col='CustomerID')
df_customers.head()
# Out:
#             Age    Education  Income  Occupation  Gender Marital Status  \
# CustomerID
# 1            67   University  124670    Official    Male         Single
# 2            22  High School  150773    Official  Female        Married
# 3            49  High School   89210  Unemployed    Male         Single
# 4            45  High School  171565    Official    Male         Single
# 5            53  High School  149031    Official    Male         Single
#
#            Settlement Size
# CustomerID
# 1                 Big City
# 2                 Big City
# 3               Small City
# 4                 Mid City
# 5                 Mid City

# %% [markdown]
# ## Inspect

# %%
print('The dimention of the dataset\n')
print(df_customers.shape)

print('\nDetail description of the dataset\n')
print(df_customers.info())
# Out:
# The dimention of the dataset
#
# (2000, 7)
#
# Detail description of the dataset
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2000 entries, 1 to 2000
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              2000 non-null   int64
#  1   Education        2000 non-null   object
#  2   Income           2000 non-null   int64
#  3   Occupation       2000 non-null   object
#  4   Gender           2000 non-null   object
#  5   Marital Status   2000 non-null   object
#  6   Settlement Size  2000 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 125.0+ KB
# None

# %% [markdown]
# ## Income Spread

# %%
# plot Income spread
plt.figure(figsize=(12, 4))
sns.rugplot(x=df_customers['Income'], height=1)
plt.xlabel('Income')
plt.show()
# plt.savefig('3.2.1 quantity rugplot.png', dpi=100)

# %% [markdown]
# ## Income with Gender

# %%
df_customers['Income'].describe()
# Out:
# count      2000.000000
# mean     120954.419000
# std       38108.824679
# min       35832.000000
# 25%       97663.250000
# 50%      115548.500000
# 75%      138072.250000
# max      309364.000000
# Name: Income, dtype: float64

# %%
# plt.figure(figsize=(12, 8))
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.histplot(data=df_customers, x='Income', kde=True, ax=ax[0])
sns.histplot(data=df_customers, x='Income', hue='Gender', kde=True, ax=ax[1])
plt.show()
# plt.savefig('3.2.1 quantity rugplot.png', dpi=1200)

# %% [markdown]
# ## Age with Gender

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.histplot(data=df_customers, x='Age', kde=True, ax=ax[0])
sns.histplot(data=df_customers, x='Age', kde=True, hue='Gender', ax=ax[1]) 
plt.show()
# plt.savefig('output/output.png', dpi=800)

# %% [markdown]
# ## Age vs Income with Gender

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data=df_customers, x='Age', y='Income')
plt.title('Age vs Income')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.histplot(data=df_customers, x='Age', y='Income', kde=False, cbar=True, ax=ax[0])
sns.kdeplot(data=df_customers, x='Age', y='Income', hue='Gender', fill=False, ax=ax[1])
plt.show()

# %% [markdown]
# ## Age vs Income with Occupation

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 10))
sns.histplot(data=df_customers, x='Age', y='Income', hue='Occupation', ax=ax[0])
sns.kdeplot(data=df_customers, x='Age', y='Income', hue='Occupation', ax=ax[1])
# plt.savefig('output/output.png', dpi=800)
plt.show()

# %% [markdown]
# ## Income of different Genders

# %%
plt.figure(figsize=(8, 8))
sns.boxplot(data=df_customers, y='Income', x='Gender')
plt.xlabel('Combined')
plt.show()

# %% [markdown]
# ## Income and Age of different Settlement Size

# %%
# plt.figure(figsize=(8, 8))
fig, ax = plt.subplots(1, 2, figsize=(15, 8))
sns.boxplot(data=df_customers, y='Income', x='Settlement Size', ax=ax[0])
sns.boxplot(data=df_customers, y='Age', x='Settlement Size', ax=ax[1])
plt.show()
